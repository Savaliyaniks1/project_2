# %% [markdown]
# <a href="https://colab.research.google.com/github/Savaliyaniks1/project_2/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Dependancies.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset_1 collection and Processing.

# %%
# loading the csv data to a pandas Dataframe

dataset_1 = pd.read_csv(r"//content/dataset_1.csv")

# %%
# print first 5 row of the data

dataset_1.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
# print last 5 row of the data

dataset_1.tail()
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20

# %%
# Number of row and columns in the dataset
dataset_1.shape
# Out:
# (610, 10)

# %%
# checking the unique value in the columns
dataset_1['holiday'].unique()
# Out:
# array([False,  True])

# %%
# checking the unique value in columns
dataset_1['yr'].unique()
# Out:
# array([0])

# %%
# checking for missing value
dataset_1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
# getting some info about data

dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %%
# convert type of the data using datetime function

import datetime

# %%
dataset_1['dteday'] = dataset_1['dteday'].apply(lambda x: datetime.datetime.strptime(x,'%d-%m-%Y'))

# %%
dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB

# %%
# convert types of data in holiday from boolean to int.

dataset_1['holiday'] = dataset_1['holiday'].astype(int)

# %%
## remove column using drop function.

dataset_1.drop(['yr','season'],axis = 1,inplace = True)

# %%
dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   mnth        610 non-null    int64
#  3   hr          610 non-null    int64
#  4   holiday     610 non-null    int64
#  5   weekday     610 non-null    int64
#  6   weathersit  610 non-null    int64
#  7   temp        610 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(6)
# memory usage: 38.2 KB

# %%
# statistical measurment of the data

dataset_1.describe()
# Out:
#           instant                         dteday   mnth          hr  \
# count  610.000000                            610  610.0  610.000000
# mean   305.500000  2011-01-13 19:47:24.590163968    1.0   11.795082
# min      1.000000            2011-01-01 00:00:00    1.0    0.000000
# 25%    153.250000            2011-01-07 00:00:00    1.0    6.000000
# 50%    305.500000            2011-01-14 00:00:00    1.0   12.000000
# 75%    457.750000            2011-01-21 00:00:00    1.0   18.000000
# max    610.000000            2011-01-28 00:00:00    1.0   23.000000
# std    176.236111                            NaN    0.0    6.852107
#
#           holiday     weekday  weathersit        temp
# count  610.000000  610.000000  610.000000  610.000000
# mean     0.039344    2.977049    1.477049    0.196885
# min      0.000000    0.000000    1.000000    0.020000
# 25%      0.000000    1.000000    1.000000    0.160000
# 50%      0.000000    3.000000    1.000000    0.200000
# ...

# %% [markdown]
# Dataset_2 collection and Processing.

# %%
## excel dataset load using read_excel function.

dataset_2 = pd.read_excel(r"/content/dataset_2.xlsx")
print(dataset_2)
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
# print first 5 row of the data

dataset_2.head(5)
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
# Number of row and columns in the dataset

dataset_2.shape
# Out:
# (610, 8)

# %%
# Remove unnecessary columns using drop function.

dataset_2.drop(['Unnamed: 0'],axis = 1,inplace = True)

# %%
dataset_2.head()
# Out:
#    instant   atemp   hum  windspeed  casual  registered  cnt
# 0        1  0.2879  0.81        0.0       3          13   16
# 1        2  0.2727  0.80        0.0       8          32   40
# 2        3  0.2727  0.80        0.0       5          27   32
# 3        4  0.2879  0.75        0.0       3          10   13
# 4        5  0.2879  0.75        0.0       0           1    1

# %%
# Checking the unique value in the columns

dataset_2['windspeed'].unique()
# Out:
# array([0.    , 0.0896, 0.2537, 0.2836, 0.2985, 0.194 , 0.2239, 0.1343,
#        0.1642, 0.3284, 0.4478, 0.3582, 0.4179, 0.3881, 0.1045, 0.4925,
#        0.5522, 0.4627, 0.5224, 0.5821])

# %%
# getting some info about data

dataset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   atemp       599 non-null    float64
#  2   hum         610 non-null    float64
#  3   windspeed   610 non-null    float64
#  4   casual      610 non-null    int64
#  5   registered  610 non-null    int64
#  6   cnt         610 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 33.5 KB

# %%
# checking for missing value

dataset_2.isnull().sum()
# Out:
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
# filling missing value using fillna function.

dataset_2['atemp'].fillna(dataset_2['atemp'].mean(),inplace =True)

# %%
dataset_2.isnull().sum()
# Out:
# instant       0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# statistical measurment of the data

dataset_2.describe()
# Out:
#           instant       atemp         hum   windspeed      casual  registered  \
# count  610.000000  610.000000  610.000000  610.000000  610.000000  610.000000
# mean   305.500000    0.199935    0.562475    0.204851    4.501639   51.068852
# std    176.236111    0.078120    0.175440    0.121806    6.319945   47.021204
# min      1.000000    0.000000    0.210000    0.000000    0.000000    0.000000
# 25%    153.250000    0.151500    0.432500    0.104500    0.000000   14.000000
# 50%    305.500000    0.197000    0.520000    0.194000    2.000000   43.000000
# 75%    457.750000    0.227300    0.690000    0.283600    6.000000   70.000000
# max    610.000000    0.454500    1.000000    0.582100   47.000000  247.000000
#
#               cnt
# count  610.000000
# mean    55.570492
# std     49.316802
# min      1.000000
# 25%     16.000000
# 50%     47.000000
# 75%     79.750000
# max    249.000000

# %% [markdown]
# Dataset_3 collection and Processing.

# %%
# loading the csv data to a pandas Dataframe

dataset_3 = pd.read_csv(r"/content/dataset_3.csv")

# %%
# print first 5 row of the data

dataset_3.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
# print last 5 row of the data

dataset_3.tail(5)
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 385  0.24  0.2273  0.70     0.1940       1          61   62
# 386  0.22  0.2273  0.75     0.1343       1          57   58
# 387  0.24  0.2121  0.65     0.3582       0          26   26
# 388  0.24  0.2273  0.60     0.2239       1          22   23
# 389  0.22  0.1970  0.64     0.3582       2          26   28

# %%
# Number of row and columns in the dataset

dataset_3.shape
# Out:
# (390, 16)

# %%
# checking the unique value in the columns

dataset_3['dteday'].unique()
# Out:
# array(['29-01-2011', '30-01-2011', '31-01-2011', '01-02-2011',
#        '02-02-2011', '03-02-2011', '04-02-2011', '05-02-2011',
#        '06-02-2011', '07-02-2011', '08-02-2011', '09-02-2011',
#        '10-02-2011', '11-02-2011', '12-02-2011', '13-02-2011',
#        '14-02-2011', '28-01-2011'], dtype=object)

# %%
# checking for missing value

dataset_3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# convert type of data in holiday from boolean to int.

dataset_3['holiday'] = dataset_3['holiday'].astype(int)

# %%
## drop unnecessry column from the data

dataset_3.drop(['yr','season'],axis = 1,inplace = True)

# %%
dataset_3['dteday'] = dataset_3['dteday'].apply(lambda x: datetime.datetime.strptime(x,'%d-%m-%Y'))

# %%
dataset_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    datetime64[ns]
#  2   mnth        390 non-null    int64
#  3   hr          390 non-null    int64
#  4   holiday     390 non-null    int64
#  5   weekday     390 non-null    int64
#  6   weathersit  390 non-null    int64
#  7   temp        390 non-null    float64
#  8   atemp       390 non-null    float64
#  9   hum         390 non-null    float64
#  10  windspeed   390 non-null    float64
#  11  casual      390 non-null    int64
#  12  registered  390 non-null    int64
#  13  cnt         390 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(9)
# memory usage: 42.8 KB

# %% [markdown]
# combine_data from dataset_1 and dataset_2 using inner join method

# %%
combine_data = pd.merge(dataset_1,dataset_2, on = 'instant',how = 'inner')

# %%
print(combine_data)
# Out:
#      instant     dteday  mnth  hr  holiday  weekday  weathersit  temp   atemp  \
# 0          1 2011-01-01     1   0        0        6           1  0.24  0.2879
# 1          2 2011-01-01     1   1        0        6           1  0.22  0.2727
# 2          3 2011-01-01     1   2        0        6           1  0.22  0.2727
# 3          4 2011-01-01     1   3        0        6           1  0.24  0.2879
# 4          5 2011-01-01     1   4        0        6           1  0.24  0.2879
# ..       ...        ...   ...  ..      ...      ...         ...   ...     ...
# 605      606 2011-01-28     1  11        0        5           3  0.18  0.2121
# 606      607 2011-01-28     1  12        0        5           3  0.18  0.2121
# 607      608 2011-01-28     1  13        0        5           3  0.18  0.2121
# 608      609 2011-01-28     1  14        0        5           3  0.22  0.2727
# 609      610 2011-01-28     1  15        0        5           2  0.20  0.2576
#
# ...

# %%
combine_data.head()
# Out:
#    instant     dteday  mnth  hr  holiday  weekday  weathersit  temp   atemp  \
# 0        1 2011-01-01     1   0        0        6           1  0.24  0.2879
# 1        2 2011-01-01     1   1        0        6           1  0.22  0.2727
# 2        3 2011-01-01     1   2        0        6           1  0.22  0.2727
# 3        4 2011-01-01     1   3        0        6           1  0.24  0.2879
# 4        5 2011-01-01     1   4        0        6           1  0.24  0.2879
#
#     hum  windspeed  casual  registered  cnt
# 0  0.81        0.0       3          13   16
# 1  0.80        0.0       8          32   40
# 2  0.80        0.0       5          27   32
# 3  0.75        0.0       3          10   13
# 4  0.75        0.0       0           1    1

# %%
combine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   mnth        610 non-null    int64
#  3   hr          610 non-null    int64
#  4   holiday     610 non-null    int64
#  5   weekday     610 non-null    int64
#  6   weathersit  610 non-null    int64
#  7   temp        610 non-null    float64
#  8   atemp       610 non-null    float64
#  9   hum         610 non-null    float64
#  10  windspeed   610 non-null    float64
#  11  casual      610 non-null    int64
#  12  registered  610 non-null    int64
#  13  cnt         610 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(9)
# memory usage: 66.8 KB

# %%
combine_data.describe()
# Out:
#           instant                         dteday   mnth          hr  \
# count  610.000000                            610  610.0  610.000000
# mean   305.500000  2011-01-13 19:47:24.590163968    1.0   11.795082
# min      1.000000            2011-01-01 00:00:00    1.0    0.000000
# 25%    153.250000            2011-01-07 00:00:00    1.0    6.000000
# 50%    305.500000            2011-01-14 00:00:00    1.0   12.000000
# 75%    457.750000            2011-01-21 00:00:00    1.0   18.000000
# max    610.000000            2011-01-28 00:00:00    1.0   23.000000
# std    176.236111                            NaN    0.0    6.852107
#
#           holiday     weekday  weathersit        temp       atemp         hum  \
# count  610.000000  610.000000  610.000000  610.000000  610.000000  610.000000
# mean     0.039344    2.977049    1.477049    0.196885    0.199935    0.562475
# min      0.000000    0.000000    1.000000    0.020000    0.000000    0.210000
# ...

# %% [markdown]
# concatenated data with combine_data and dataset_3.

# %%
concat_data = pd.concat([combine_data,dataset_3],ignore_index = True)

# %%
concat_data.head()
# Out:
#    instant     dteday  mnth  hr  holiday  weekday  weathersit  temp   atemp  \
# 0        1 2011-01-01     1   0        0        6           1  0.24  0.2879
# 1        2 2011-01-01     1   1        0        6           1  0.22  0.2727
# 2        3 2011-01-01     1   2        0        6           1  0.22  0.2727
# 3        4 2011-01-01     1   3        0        6           1  0.24  0.2879
# 4        5 2011-01-01     1   4        0        6           1  0.24  0.2879
#
#     hum  windspeed  casual  registered  cnt
# 0  0.81        0.0       3          13   16
# 1  0.80        0.0       8          32   40
# 2  0.80        0.0       5          27   32
# 3  0.75        0.0       3          10   13
# 4  0.75        0.0       0           1    1

# %%
concat_data['dteday'].unique()
# Out:
# <DatetimeArray>
# ['2011-01-01 00:00:00', '2011-01-02 00:00:00', '2011-01-03 00:00:00',
#  '2011-01-04 00:00:00', '2011-01-05 00:00:00', '2011-01-06 00:00:00',
#  '2011-01-07 00:00:00', '2011-01-08 00:00:00', '2011-01-09 00:00:00',
#  '2011-01-10 00:00:00', '2011-01-11 00:00:00', '2011-01-12 00:00:00',
#  '2011-01-13 00:00:00', '2011-01-14 00:00:00', '2011-01-15 00:00:00',
#  '2011-01-16 00:00:00', '2011-01-17 00:00:00', '2011-01-18 00:00:00',
#  '2011-01-19 00:00:00', '2011-01-20 00:00:00', '2011-01-21 00:00:00',
#  '2011-01-22 00:00:00', '2011-01-23 00:00:00', '2011-01-24 00:00:00',
#  '2011-01-25 00:00:00', '2011-01-26 00:00:00', '2011-01-27 00:00:00',
#  '2011-01-28 00:00:00', '2011-01-29 00:00:00', '2011-01-30 00:00:00',
#  '2011-01-31 00:00:00', '2011-02-01 00:00:00', '2011-02-02 00:00:00',
#  '2011-02-03 00:00:00', '2011-02-04 00:00:00', '2011-02-05 00:00:00',
#  '2011-02-06 00:00:00', '2011-02-07 00:00:00', '2011-02-08 00:00:00',
# ...

# %%
concat_data.isnull().sum()
# Out:
# instant       0
# dteday        0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
concat_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     1000 non-null   int64
#  1   dteday      1000 non-null   datetime64[ns]
#  2   mnth        1000 non-null   int64
#  3   hr          1000 non-null   int64
#  4   holiday     1000 non-null   int64
#  5   weekday     1000 non-null   int64
#  6   weathersit  1000 non-null   int64
#  7   temp        1000 non-null   float64
#  8   atemp       1000 non-null   float64
#  9   hum         1000 non-null   float64
#  10  windspeed   1000 non-null   float64
#  11  casual      1000 non-null   int64
#  12  registered  1000 non-null   int64
#  13  cnt         1000 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(9)
# memory usage: 109.5 KB

# %%
concat_data.describe()
# Out:
#            instant                      dteday         mnth           hr  \
# count  1000.000000                        1000  1000.000000  1000.000000
# mean    500.500000  2011-01-22 15:56:09.600000     1.312000    11.753000
# min       1.000000         2011-01-01 00:00:00     1.000000     0.000000
# 25%     250.750000         2011-01-11 00:00:00     1.000000     6.000000
# 50%     500.500000         2011-01-22 00:00:00     1.000000    12.000000
# 75%     750.250000         2011-02-03 00:00:00     2.000000    18.000000
# max    1000.000000         2011-02-14 00:00:00     2.000000    23.000000
# std     288.819436                         NaN     0.463542     6.899101
#
#            holiday      weekday   weathersit         temp        atemp  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.024000     2.982000     1.480000     0.205900     0.211826
# min       0.000000     0.000000     1.000000     0.020000     0.000000
# ...

# %% [markdown]
# check the outlier and remove in column wise.

# %%
sns.histplot(concat_data['casual'])
# Out:
# <Axes: xlabel='casual', ylabel='Count'>

# %%
concat_data['casual'].max()
# Out:
# 62

# %%
concat_data['casual'].min()
# Out:
# 0

# %%
df = (concat_data['casual'].max()-concat_data['casual'].min())/4

# %%
df1 =concat_data['casual'].min() + df

# %%
df2 = df1 + df

# %%
df3 = df2 + df

# %%
df4 = df3 + df

# %%
iqr = df3 - df1

# %%
print(iqr)
# Out:
# 31.0

# %%
plt.boxplot(concat_data['casual'])
plt.title('box plot of casual column')
# Out:
# Text(0.5, 1.0, 'box plot of casual column')

# %%
concat_data_no_outlier = concat_data[(concat_data.casual>0)&(concat_data.casual<62)]

plt.boxplot(np.log(concat_data_no_outlier ['casual']))
plt.title('box plot of casual column')
# Out:
# Text(0.5, 1.0, 'box plot of casual column')

# %%
plt.boxplot(concat_data['registered'])
plt.title('box plot of casual registered')
# Out:
# Text(0.5, 1.0, 'box plot of casual registered')

# %%
concat_data['registered'].max()
# Out:
# 247

# %%
concat_data['registered'].min()
# Out:
# 0

# %%
df = (concat_data['registered'].max() - concat_data['registered'].min())/4

# %%
df1 = concat_data['registered'].min() + df

# %%
df2 = df + df1

# %%
df3 = df2 + df

# %%
df4 = df3 + df

# %%
iqr = df3 - df1
print(iqr)
# Out:
# 123.5

# %%
concat_data_no_outlier = concat_data[(concat_data.registered>0)&(concat_data.registered<247)]


plt.boxplot(np.log(concat_data_no_outlier['registered']))
plt.title('box plot of casual registered')
# Out:
# Text(0.5, 1.0, 'box plot of casual registered')

# %%
plt.boxplot(concat_data['cnt'])
plt.title('box plot of casual cnt')
# Out:
# Text(0.5, 1.0, 'box plot of casual cnt')

# %%
concat_data['registered'].max()
# Out:
# 247

# %%
concat_data['cnt'].min()
# Out:
# 1

# %%
df = (concat_data['registered'].max() - concat_data['cnt'].min())/4

# %%
df1 = concat_data['cnt'].min() + df

# %%
df2 = df1 + df

# %%
df3 = df2 + df

# %%
df4 = df3 + df

# %%
iqr = df3 - df1
print(iqr)
# Out:
# 123.0

# %%
concat_data_no_outlier = concat_data[(concat_data.cnt>1)&(concat_data.cnt<492)]


plt.boxplot(np.log(concat_data_no_outlier['cnt']))
plt.title('box plot of casual cnt')
# Out:
# Text(0.5, 1.0, 'box plot of casual cnt')

# %% [markdown]
# Check correletion of data.

# %%
concat_data.corr()
# Out:
#              instant    dteday      mnth        hr   holiday   weekday  \
# instant     1.000000  0.999540  0.802477  0.000060 -0.063013  0.008157
# dteday      0.999540  1.000000  0.804299 -0.022421 -0.068456  0.010248
# mnth        0.802477  0.804299  1.000000 -0.025646 -0.105600  0.034710
# hr          0.000060 -0.022421 -0.025646  1.000000 -0.005753  0.007531
# holiday    -0.063013 -0.068456 -0.105600 -0.005753  1.000000 -0.148682
# weekday     0.008157  0.010248  0.034710  0.007531 -0.148682  1.000000
# weathersit  0.030439  0.033310  0.014061 -0.055802  0.165443  0.060007
# temp        0.023406  0.022342  0.159660  0.203512 -0.059728 -0.081776
# atemp       0.077546  0.078681  0.192216  0.148524 -0.072091 -0.051646
# hum         0.062116  0.073485  0.066587 -0.194853 -0.037542  0.062469
# windspeed  -0.057837 -0.064148 -0.029383  0.116640 -0.001111 -0.056754
# casual      0.071259  0.065002  0.088326  0.204476 -0.000944 -0.047363
# ...

# %%
## convert object date column into float value using numeric method.

concat_data['dteday'] = pd.to_numeric(concat_data['dteday'], errors='coerce')

# %% [markdown]
# Check the skewness of the data.

# %%
concat_data.skew(axis =0, skipna=True)
# Out:
# instant       0.000000
# dteday        0.007008
# mnth          0.812772
# hr           -0.063524
# holiday       6.229578
# weekday       0.021925
# weathersit    1.044098
# temp          0.547997
# atemp         0.435927
# hum           0.436893
# windspeed     0.433675
# casual        3.414105
# registered    1.296723
# cnt           1.137709
# dtype: float64

# %%
concat_data['dteday']=pd.to_datetime(concat_data['dteday'])
print(concat_data['dteday'])
# Out:
# 0     2011-01-01
# 1     2011-01-01
# 2     2011-01-01
# 3     2011-01-01
# 4     2011-01-01
#          ...
# 995   2011-01-28
# 996   2011-01-28
# 997   2011-01-28
# 998   2011-01-28
# 999   2011-01-29
# Name: dteday, Length: 1000, dtype: datetime64[ns]

# %%
## convert pandas dataframe into excel form.

concat_data.to_excel("project_2.xlsx")
